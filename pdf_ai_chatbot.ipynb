# %%
# !pip install groq pdfplumber chromadb sentence-transformers gradio numpy
# !pip install google-generativeai
# Out:
# Requirement already satisfied: groq in c:\users\abhisek\documents\python\lib\site-packages (1.5.0)
# Requirement already satisfied: pdfplumber in c:\users\abhisek\documents\python\lib\site-packages (0.11.10)
# Requirement already satisfied: chromadb in c:\users\abhisek\documents\python\lib\site-packages (1.5.9)
# Requirement already satisfied: sentence-transformers in c:\users\abhisek\documents\python\lib\site-packages (5.6.0)
# Requirement already satisfied: gradio in c:\users\abhisek\documents\python\lib\site-packages (6.19.0)
# Requirement already satisfied: numpy in c:\users\abhisek\documents\python\lib\site-packages (1.26.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\abhisek\documents\python\lib\site-packages (from groq) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\abhisek\documents\python\lib\site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\abhisek\documents\python\lib\site-packages (from groq) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\abhisek\documents\python\lib\site-packages (from groq) (2.13.4)
# Requirement already satisfied: sniffio in c:\users\abhisek\documents\python\lib\site-packages (from groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\abhisek\documents\python\lib\site-packages (from groq) (4.15.0)
# Requirement already satisfied: pdfminer.six==20260107 in c:\users\abhisek\documents\python\lib\site-packages (from pdfplumber) (20260107)
# Requirement already satisfied: Pillow>=12.2.0 in c:\users\abhisek\documents\python\lib\site-packages (from pdfplumber) (12.2.0)
# Requirement already satisfied: pypdfium2>=5.9.0 in c:\users\abhisek\documents\python\lib\site-packages (from pdfplumber) (5.10.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\abhisek\documents\python\lib\site-packages (from pdfminer.six==20260107->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\abhisek\documents\python\lib\site-packages (from pdfminer.six==20260107->pdfplumber) (43.0.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (2.14.2)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\abhisek\documents\python\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.49.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (1.81.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (0.25.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (36.0.2)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (3.11.9)
# Requirement already satisfied: rich>=10.11.0 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\abhisek\documents\python\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\abhisek\documents\python\lib\site-packages (from sentence-transformers) (5.12.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\abhisek\documents\python\lib\site-packages (from sentence-transformers) (1.20.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\abhisek\documents\python\lib\site-packages (from sentence-transformers) (2.12.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\abhisek\documents\python\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\abhisek\documents\python\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (0.138.0)
# Requirement already satisfied: gradio-client==2.5.0 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (2.5.0)
# Requirement already satisfied: groovy~=0.1 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.4.1 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (0.4.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: packaging in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<4.0,>=1.0 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pydub<1.0 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart<1.0,>=0.0.18 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (0.0.32)
# Requirement already satisfied: pytz>=2017.2 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (2024.1)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<2.0,>=1.0.1 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (1.3.1)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in c:\users\abhisek\documents\python\lib\site-packages (from gradio) (0.14.0)
# Requirement already satisfied: fsspec in c:\users\abhisek\documents\python\lib\site-packages (from gradio-client==2.5.0->gradio) (2024.6.1)
# Requirement already satisfied: idna>=2.8 in c:\users\abhisek\documents\python\lib\site-packages (from anyio<5,>=3.5.0->groq) (3.7)
# Requirement already satisfied: pyproject_hooks in c:\users\abhisek\documents\python\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\abhisek\documents\python\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\abhisek\documents\python\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\abhisek\documents\python\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in c:\users\abhisek\documents\python\lib\site-packages (from httpx<1,>=0.23.0->groq) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\abhisek\documents\python\lib\site-packages (from httpx<1,>=0.23.0->groq) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\abhisek\documents\python\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: click>=8.4.0 in c:\users\abhisek\documents\python\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\abhisek\documents\python\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\abhisek\documents\python\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\abhisek\documents\python\lib\site-packages (from jsonschema>=4.19.0->chromadb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\abhisek\documents\python\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\abhisek\documents\python\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\abhisek\documents\python\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\abhisek\documents\python\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\abhisek\documents\python\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\abhisek\documents\python\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\abhisek\documents\python\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.34.2)
# Requirement already satisfied: requests-oauthlib in c:\users\abhisek\documents\python\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\abhisek\documents\python\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\abhisek\documents\python\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in c:\users\abhisek\documents\python\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.14.1)
# Requirement already satisfied: flatbuffers in c:\users\abhisek\documents\python\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in c:\users\abhisek\documents\python\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\abhisek\documents\python\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.42.1 in c:\users\abhisek\documents\python\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-proto==1.42.1 in c:\users\abhisek\documents\python\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in c:\users\abhisek\documents\python\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.63b1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abhisek\documents\python\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abhisek\documents\python\lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\abhisek\documents\python\lib\site-packages (from pydantic<3,>=1.9.0->groq) (2.46.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\abhisek\documents\python\lib\site-packages (from pydantic-settings>=2.0->chromadb) (0.21.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\abhisek\documents\python\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abhisek\documents\python\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\abhisek\documents\python\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\abhisek\documents\python\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: setuptools<82 in c:\users\abhisek\documents\python\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\abhisek\documents\python\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\abhisek\documents\python\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\abhisek\documents\python\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\abhisek\documents\python\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\abhisek\documents\python\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.8.0 in c:\users\abhisek\documents\python\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in c:\users\abhisek\documents\python\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\abhisek\documents\python\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\abhisek\documents\python\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\abhisek\documents\python\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\abhisek\documents\python\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\abhisek\documents\python\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\abhisek\documents\python\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\abhisek\documents\python\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.24.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\abhisek\documents\python\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20260107->pdfplumber) (1.17.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abhisek\documents\python\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\abhisek\documents\python\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\abhisek\documents\python\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: pycparser in c:\users\abhisek\documents\python\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20260107->pdfplumber) (2.21)
# Requirement already satisfied: google-generativeai in c:\users\abhisek\documents\python\lib\site-packages (0.8.6)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\abhisek\documents\python\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\abhisek\documents\python\lib\site-packages (from google-generativeai) (2.31.0)
# Requirement already satisfied: google-api-python-client in c:\users\abhisek\documents\python\lib\site-packages (from google-generativeai) (2.197.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\abhisek\documents\python\lib\site-packages (from google-generativeai) (2.55.0)
# Requirement already satisfied: protobuf in c:\users\abhisek\documents\python\lib\site-packages (from google-generativeai) (5.29.6)
# Requirement already satisfied: pydantic in c:\users\abhisek\documents\python\lib\site-packages (from google-generativeai) (2.13.4)
# Requirement already satisfied: tqdm in c:\users\abhisek\documents\python\lib\site-packages (from google-generativeai) (4.66.5)
# Requirement already satisfied: typing-extensions in c:\users\abhisek\documents\python\lib\site-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\abhisek\documents\python\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.28.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in c:\users\abhisek\documents\python\lib\site-packages (from google-api-core->google-generativeai) (1.75.0)
# Requirement already satisfied: requests<3.0.0,>=2.33.0 in c:\users\abhisek\documents\python\lib\site-packages (from google-api-core->google-generativeai) (2.34.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abhisek\documents\python\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\abhisek\documents\python\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (43.0.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\abhisek\documents\python\lib\site-packages (from google-api-python-client->google-generativeai) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\abhisek\documents\python\lib\site-packages (from google-api-python-client->google-generativeai) (0.4.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\abhisek\documents\python\lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abhisek\documents\python\lib\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\abhisek\documents\python\lib\site-packages (from pydantic->google-generativeai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\abhisek\documents\python\lib\site-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\abhisek\documents\python\lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\abhisek\documents\python\lib\site-packages (from cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (1.17.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.41.0 in c:\users\abhisek\documents\python\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.81.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.41.0 in c:\users\abhisek\documents\python\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\users\abhisek\documents\python\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\abhisek\documents\python\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\abhisek\documents\python\lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhisek\documents\python\lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\abhisek\documents\python\lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\abhisek\documents\python\lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (2024.8.30)
# Requirement already satisfied: pycparser in c:\users\abhisek\documents\python\lib\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.21)

# %%
import os
import uuid
import numpy as np
import pdfplumber
import chromadb
from sentence_transformers import SentenceTransformer
from groq import Groq
import gradio as gr
from typing import List, Dict, Optional

print("All imports successful")
# Out:
# All imports successful

# %%
GROQ_API_KEY = "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"

EMBEDDING_MODEL = "all-MiniLM-L6-v2"

CHUNK_SIZE = 500
CHUNK_OVERLAP = 100

TOP_K_RESULTS = 5

COLLECTION_NAME = "pdf_chatbot"

LLM_MODEL = "llama-3.1-8b-instant"

print("Configuration loaded")
print(f"LLM: {LLM_MODEL} via Groq (free)")
print(f"Embeddings: {EMBEDDING_MODEL} (runs locally, free)")
print(f"Vector DB: ChromaDB (local, free)")
# Out:
# Configuration loaded
# LLM: llama-3.1-8b-instant via Groq (free)
# Embeddings: all-MiniLM-L6-v2 (runs locally, free)
# Vector DB: ChromaDB (local, free)

# %%
class PDFProcessor:
    """
    Extracts text from PDF files while tracking page numbers.
    Page numbers are critical for source citations in answers.
    """

    def extract_text_with_pages(self, pdf_path: str) -> List[Dict]:
        pages = []
        filename = os.path.basename(pdf_path)

        try:
            with pdfplumber.open(pdf_path) as pdf:
                total_pages = len(pdf.pages)
                print(f"'{filename}' has {total_pages} pages")

                for page_num, page in enumerate(pdf.pages, start=1):
                    text = page.extract_text()

                    if text and text.strip():
                        pages.append({
                            "page_number": page_num,
                            "text": text.strip(),
                            "source": filename
                        })
                    else:
                        print(f"Page {page_num} appears blank or unreadable")

        except Exception as e:
            print(f"Error reading '{filename}': {e}")

        print(f"Extracted {len(pages)} pages with content")
        return pages

processor = PDFProcessor()
print("PDFProcessor initialized")
# Out:
# PDFProcessor initialized

# %%
class TextChunker:
    def __init__(self, chunk_size: int = CHUNK_SIZE, chunk_overlap: int = CHUNK_OVERLAP):
        self.chunk_size = chunk_size
        self.chunk_overlap = chunk_overlap

    def chunk_pages(self, pages: List[Dict]) -> List[Dict]:
        all_chunks = []

        for page in pages:
            page_text = page["text"]
            sub_chunks = self._split_text(page_text)

            for idx, chunk_text in enumerate(sub_chunks):
                all_chunks.append({
                    "chunk_id": str(uuid.uuid4()),
                    "text": chunk_text,
                    "page_number": page["page_number"],
                    "source": page["source"],
                    "chunk_index": idx
                })

        return all_chunks

    def _split_text(self, text: str) -> List[str]:
        chunks = []
        start = 0

        while start < len(text):
            end = start + self.chunk_size
            chunk = text[start:end].strip()

            if chunk:
                chunks.append(chunk)

            start += self.chunk_size - self.chunk_overlap

        return chunks

chunker = TextChunker()
print("TextChunker initialized")
# Out:
# TextChunker initialized

# %%
class VectorStore:
    """
    Manages embeddings and similarity search.
    Both the embedding model and ChromaDB are completely free and run locally.
    """

    def __init__(self):
        print("Loading embedding model (first time may take around 1 minute)...")
        self.embedder = SentenceTransformer(EMBEDDING_MODEL)
        print(f"Loaded: {EMBEDDING_MODEL}")

        self.chroma_client = chromadb.Client()
        self.collection = self.chroma_client.get_or_create_collection(
            name=COLLECTION_NAME,
            metadata={"hnsw:space": "cosine"}
        )
        print(f"ChromaDB collection ready")

    def add_chunks(self, chunks: List[Dict]):
        if not chunks:
            print("No chunks to add")
            return

        print(f"Embedding {len(chunks)} chunks...")

        texts = [chunk["text"] for chunk in chunks]
        embeddings = self.embedder.encode(
            texts,
            show_progress_bar=True,
            batch_size=32
        ).tolist()

        self.collection.add(
            ids=[chunk["chunk_id"] for chunk in chunks],
            embeddings=embeddings,
            documents=texts,
            metadatas=[{
                "page_number": chunk["page_number"],
                "source": chunk["source"],
                "chunk_index": chunk["chunk_index"]
            } for chunk in chunks]
        )

        print(f"Stored {len(chunks)} chunks in vector database")

    def search(self, query: str, top_k: int = TOP_K_RESULTS) -> List[Dict]:
        query_embedding = self.embedder.encode([query]).tolist()

        results = self.collection.query(
            query_embeddings=query_embedding,
            n_results=min(top_k, self.collection.count())
        )

        retrieved_chunks = []
        for i in range(len(results["ids"][0])):
            retrieved_chunks.append({
                "text": results["documents"][0][i],
                "page_number": results["metadatas"][0][i]["page_number"],
                "source": results["metadatas"][0][i]["source"],
                "relevance_score": 1 - results["distances"][0][i]
            })

        return retrieved_chunks

    def clear(self):
        self.chroma_client.delete_collection(COLLECTION_NAME)
        self.collection = self.chroma_client.get_or_create_collection(
            name=COLLECTION_NAME,
            metadata={"hnsw:space": "cosine"}
        )
        print("Vector store cleared")

    def count(self) -> int:
        return self.collection.count()

vector_store = VectorStore()
# Out:
# Loading embedding model (first time may take around 1 minute)...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Loaded: all-MiniLM-L6-v2
# ChromaDB collection ready

# %%
class PDFChatBot:
    """
    Uses Groq (free) with Llama 3.1 to answer questions.
    Groq API is OpenAI-compatible, making it easy to use.
    """

    SYSTEM_PROMPT = """You are an expert document analyst assistant.
Your job is to answer questions based ONLY on the provided PDF document excerpts.

Rules you must follow:
1. ONLY use information from the provided context, never use outside knowledge
2. ALWAYS cite sources: mention the document name and page number for every claim
3. If the answer is not in the provided context, say: I could not find this information in the uploaded documents
4. Be concise but complete, do not pad your answers
5. If multiple sources support a point, mention all of them
6. Use bullet points for clarity when listing multiple facts

Citation format: (Source: [filename], Page [X])"""

    def __init__(self, api_key: str):
        # Groq client - completely free
        self.client = Groq(api_key=api_key)
        self.chat_history = []

    def _build_context_block(self, chunks: List[Dict]) -> str:
        context_parts = []
        for i, chunk in enumerate(chunks, 1):
            context_parts.append(
                f"[EXCERPT {i}]\n"
                f"Document: {chunk['source']}\n"
                f"Page: {chunk['page_number']}\n"
                f"Relevance: {chunk['relevance_score']:.2%}\n"
                f"Content:\n{chunk['text']}"
            )
        return "\n\n" + "-" * 50 + "\n\n".join(context_parts)

    def ask(self, question: str, retrieved_chunks: List[Dict]) -> str:
        context = self._build_context_block(retrieved_chunks)

        user_message = f"""Here are the relevant excerpts from the uploaded PDF documents:

{context}

-------------------------------------------------

Based on the above excerpts, please answer this question:
{question}

Remember to cite the document name and page number for each claim."""

        # Add to history
        self.chat_history.append({
            "role": "user",
            "content": user_message
        })

        # Groq API call (free)
        # This uses the same OpenAI-compatible format
        response = self.client.chat.completions.create(
            model=LLM_MODEL,
            max_tokens=1024,
            messages=[
                {"role": "system", "content": self.SYSTEM_PROMPT}
            ] + self.chat_history
        )

        answer = response.choices[0].message.content

        self.chat_history.append({
            "role": "assistant",
            "content": answer
        })

        return answer

    def ask_streaming(self, question: str, retrieved_chunks: List[Dict]):
        """
        Streaming version - yields text token by token (bonus feature).
        Groq supports streaming natively and it is free.
        """
        context = self._build_context_block(retrieved_chunks)

        user_message = f"""Here are the relevant excerpts from the uploaded PDF documents:

{context}

-------------------------------------------------

Based on the above excerpts, please answer this question:
{question}

Remember to cite the document name and page number for each claim."""

        self.chat_history.append({"role": "user", "content": user_message})
        full_response = ""

        # Groq streaming API call (free)
        stream = self.client.chat.completions.create(
            model=LLM_MODEL,
            max_tokens=1024,
            messages=[
                {"role": "system", "content": self.SYSTEM_PROMPT}
            ] + self.chat_history,
            stream=True
        )

        for chunk in stream:
            text = chunk.choices[0].delta.content
            if text is not None:
                full_response += text
                yield text

        self.chat_history.append({"role": "assistant", "content": full_response})

    def clear_history(self):
        self.chat_history = []
        print("Chat history cleared")

chatbot = PDFChatBot(api_key=GROQ_API_KEY)
print("Chatbot initialized with free Groq API")
# Out:
# Chatbot initialized with free Groq API

# %%
uploaded_file_names = []

def process_uploaded_pdfs(files) -> str:
    global uploaded_file_names

    if not files:
        return "No files selected. Please upload at least one PDF."

    vector_store.clear()
    chatbot.clear_history()
    uploaded_file_names = []
    all_chunks = []

    print(f"Processing {len(files)} file(s)...")

    for file in files:
        filename = os.path.basename(file.name)
        print(f"Processing: {filename}")

        pages = processor.extract_text_with_pages(file.name)

        if not pages:
            print(f"Could not extract text from {filename}")
            continue

        chunks = chunker.chunk_pages(pages)
        all_chunks.extend(chunks)
        uploaded_file_names.append(filename)

        print(f"{filename}: {len(pages)} pages -> {len(chunks)} chunks")

    if not all_chunks:
        return "Could not extract text from any uploaded PDFs."

    vector_store.add_chunks(all_chunks)

    status = (
        f"Ready. Processed {len(uploaded_file_names)} document(s):\n"
        + "\n".join(f"  - {name}" for name in uploaded_file_names)
        + f"\n\nTotal chunks in database: {vector_store.count()}"
        + f"\nYou can now ask questions in the chat."
    )
    return status


def chat_response(user_message: str, history: list) -> tuple:
    if not user_message.strip():
        return history, "", ""

    if not uploaded_file_names:
        history.append({"role": "user", "content": user_message})
        history.append({"role": "assistant", "content": "Please upload and process a PDF first."})
        return history, "", ""

    retrieved = vector_store.search(user_message, top_k=TOP_K_RESULTS)

    if not retrieved:
        history.append({"role": "user", "content": user_message})
        history.append({"role": "assistant", "content": "No relevant content found. Try rephrasing your question."})
        return history, "", ""

    answer = chatbot.ask(user_message, retrieved)
    sources_text = format_sources(retrieved)

    # Gradio 6.0 requires this dict format instead of [user, assistant] list
    history.append({"role": "user", "content": user_message})
    history.append({"role": "assistant", "content": answer})

    return history, "", sources_text


def format_sources(chunks: List[Dict]) -> str:
    if not chunks:
        return "No sources retrieved."

    lines = ["### Sources Used\n"]
    seen_pages = set()

    for i, chunk in enumerate(chunks, 1):
        key = f"{chunk['source']}_p{chunk['page_number']}"
        if key in seen_pages:
            continue
        seen_pages.add(key)

        lines.append(
            f"**[{i}] {chunk['source']} - Page {chunk['page_number']}**  \n"
            f"Relevance: {chunk['relevance_score']:.0%}  \n"
            f"Excerpt:  \n"
            f"> {chunk['text'][:200].replace(chr(10), ' ')}...  \n"
        )

    return "\n".join(lines)


def clear_chat_history():
    chatbot.clear_history()
    return [], ""

print("Helper functions defined")
# Out:
# Helper functions defined

# %%
with gr.Blocks(title="PDF AI Chatbot") as demo:

    gr.Markdown("""
    # PDF AI Chatbot
    Upload your PDF documents and ask questions. Get answers with page citations.
    """)

    with gr.Row():

        with gr.Column(scale=1, min_width=300):
            gr.Markdown("## Upload Documents")

            file_input = gr.File(
                label="Select PDF files (up to 50MB each)",
                file_count="multiple",
                file_types=[".pdf"],
                height=150
            )

            process_btn = gr.Button(
                "Process PDFs",
                variant="primary",
                size="lg"
            )

            status_box = gr.Textbox(
                label="Processing Status",
                value="Upload PDFs and click Process PDFs to begin.",
                interactive=False,
                lines=6
            )

            gr.Markdown("---")
            gr.Markdown("""
            Tips:
            - Upload multiple PDFs at once
            - Ask follow-up questions naturally
            - Check Sources panel for citations
            - Use Clear Chat to start over
            """)

        with gr.Column(scale=2):
            gr.Markdown("## Chat with your Documents")

            chatbot_ui = gr.Chatbot(
                label="Conversation",
                height=400,
                show_label=True
            )

            with gr.Row():
                msg_box = gr.Textbox(
                    placeholder="Ask a question about your PDF...",
                    label="",
                    scale=5,
                    lines=1,
                    max_lines=3
                )
                send_btn = gr.Button("Send", variant="primary", scale=1)

            with gr.Row():
                clear_btn = gr.Button("Clear Chat", variant="secondary", scale=1)
                gr.Markdown("Press Enter or click Send", scale=3)

    gr.Markdown("---")
    gr.Markdown("## Retrieved Sources and Excerpts")
    sources_display = gr.Markdown(
        value="Sources will appear here after you ask a question."
    )

    process_btn.click(
        fn=process_uploaded_pdfs,
        inputs=[file_input],
        outputs=[status_box]
    )

    send_btn.click(
        fn=chat_response,
        inputs=[msg_box, chatbot_ui],
        outputs=[chatbot_ui, msg_box, sources_display]
    )

    msg_box.submit(
        fn=chat_response,
        inputs=[msg_box, chatbot_ui],
        outputs=[chatbot_ui, msg_box, sources_display]
    )

    clear_btn.click(
        fn=clear_chat_history,
        outputs=[chatbot_ui, sources_display]
    )

print("Gradio UI built successfully")
# Out:
# Gradio UI built successfully

# %%
demo.launch(
    share=True,
    debug=False,
    show_error=True
)


#demo.launch(
#    share=True,
#    server_name="0.0.0.0",
#    debug=True
#)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
print("=" * 60)
print("COMPONENT TEST SUITE")
print("=" * 60)

# Test 1: Chunking
print("\nTest 1: Text Chunking")
sample_pages = [
    {"page_number": 1, "text": "A" * 1200, "source": "test.pdf"},
    {"page_number": 2, "text": "B" * 300,  "source": "test.pdf"}
]
test_chunks = chunker.chunk_pages(sample_pages)
print(f"1200 + 300 chars -> {len(test_chunks)} chunks")

# Test 2: Embeddings
print("\nTest 2: Embeddings")
test_embed = vector_store.embedder.encode(["Hello world"])
print(f"Embedding shape: {test_embed.shape} (expected (1, 384))")

# Test 3: Vector Search
print("\nTest 3: Vector Search")
sample_chunks = [
    {"chunk_id": str(uuid.uuid4()), "text": "The sky is blue.", "page_number": 1, "source": "test.pdf", "chunk_index": 0},
    {"chunk_id": str(uuid.uuid4()), "text": "Python is a programming language.", "page_number": 2, "source": "test.pdf", "chunk_index": 0},
]
vector_store.clear()
vector_store.add_chunks(sample_chunks)
results = vector_store.search("What color is the sky?", top_k=1)
print(f"Query result: '{results[0]['text']}' (Page {results[0]['page_number']})")
assert "sky" in results[0]["text"].lower(), "Retrieval test failed"
print("Retrieval test passed")
vector_store.clear()

# Test 4: Groq API
print("\nTest 4: Groq API Connection (Free)")
test_client = Groq(api_key=GROQ_API_KEY)
test_response = test_client.chat.completions.create(
    model=LLM_MODEL,
    max_tokens=20,
    messages=[{"role": "user", "content": "Say: API connection works"}]
)
print(f"Groq says: {test_response.choices[0].message.content}")

print("\n" + "=" * 60)
print("ALL TESTS PASSED")
print("=" * 60)
# Out:
# ============================================================
# COMPONENT TEST SUITE
# ============================================================
#
# Test 1: Text Chunking
# 1200 + 300 chars -> 4 chunks
#
# Test 2: Embeddings
# Embedding shape: (1, 384) (expected (1, 384))
#
# Test 3: Vector Search
# Vector store cleared
# Embedding 2 chunks...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Stored 2 chunks in vector database
# Query result: 'The sky is blue.' (Page 1)
# Retrieval test passed
# Vector store cleared
#
# Test 4: Groq API Connection (Free)
# Groq says: API connection established successfully.
#
# ============================================================
# ALL TESTS PASSED
# ============================================================

# %%
# Generate requirements.txt for HuggingFace deployment

requirements = """groq
pdfplumber
chromadb
sentence-transformers
gradio
numpy
"""

with open("requirements.txt", "w") as f:
    f.write(requirements)

print("requirements.txt saved")
print("\nFor HuggingFace Spaces deployment:")
print("1. Go to https://huggingface.co and create a free account")
print("2. Create a new Space with Gradio SDK")
print("3. Upload app.py and requirements.txt")
print("4. Go to Settings -> Variables and Secrets")
print("5. Add secret: Name = GROQ_API_KEY, Value = your key")
print("6. Your app will be live at huggingface.co/spaces/YOUR_NAME/pdf-chatbot")
# Out:
# requirements.txt saved
#
# For HuggingFace Spaces deployment:
# 1. Go to https://huggingface.co and create a free account
# 2. Create a new Space with Gradio SDK
# 3. Upload app.py and requirements.txt
# 4. Go to Settings -> Variables and Secrets
# 5. Add secret: Name = GROQ_API_KEY, Value = your key
# 6. Your app will be live at huggingface.co/spaces/YOUR_NAME/pdf-chatbot
